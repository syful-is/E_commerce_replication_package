# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
import statistics
import os

os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

#df1=pd.read_csv("RQ1_ecommerce_version_1.csv",low_memory=False)
df2=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False )

# %% [markdown]
# **Topic Mapped by Ecommerce Platform**

# %%
import re
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('New_topic') 


 
Others=[]
E_commerce= []
Magento= []
OsCommerce=[]
Satchmo= []
Virtuemart= []
Ubercart= []
Prestashop= []
Opencart= []
Zencart=[]
nopCommerce= []
Shopify=[]
Hybris=[]
Broadleaf_commerce=[]
Woocommerce=[]
BigCommerce=[]
Sylius=[]
Django_oscar=[]
Virtocommerce=[]

Topic=[]

#no of posts after manual categorization
n_Others=30868
n_E_commerce= 3121
n_Magento= 38186
n_OsCommerce=320
n_Satchmo= 118
n_Virtuemart= 680
n_Ubercart= 327
n_Prestashop= 5788
n_Opencart= 5306
n_Zencart=266
n_nopCommerce= 1104
n_Shopify=4702
n_Hybris=1288
n_Broadleaf_commerce=295
n_Woocommerce=20263
n_BigCommerce=1306
n_Sylius=578
n_Django_oscar=318
n_Virtocommerce=115

 

for i in range(0, 17):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Ecommerce']).count('Others'))/n_Others)*100)
    E_commerce.append(((list(df4['Ecommerce']).count('E-commerce'))/n_E_commerce)*100)
    Magento.append(((list(df4['Ecommerce']).count('Magento'))/n_Magento)*100)
    OsCommerce.append(((list(df4['Ecommerce']).count('OsCommerce'))/n_OsCommerce)*100)
    Satchmo.append(((list(df4['Ecommerce']).count('Satchmo'))/n_Satchmo)*100)
    Virtuemart.append(((list(df4['Ecommerce']).count('Virtuemart'))/n_Virtuemart)*100)
    Ubercart.append(((list(df4['Ecommerce']).count('Ubercart'))/n_Ubercart)*100)
    Prestashop.append(((list(df4['Ecommerce']).count('Prestashop'))/n_Prestashop)*100)
    Opencart.append(((list(df4['Ecommerce']).count('Opencart'))/n_Opencart)*100)
    Zencart.append(((list(df4['Ecommerce']).count('Zencart'))/n_Zencart)*100)
    nopCommerce.append(((list(df4['Ecommerce']).count('nopCommerce'))/n_nopCommerce)*100)
    Shopify.append(((list(df4['Ecommerce']).count('Shopify'))/n_Shopify)*100)
    Hybris.append(((list(df4['Ecommerce']).count('Hybris'))/n_Hybris)*100)
    Broadleaf_commerce.append(((list(df4['Ecommerce']).count('Broadleaf-commerce'))/n_Broadleaf_commerce)*100)
    Woocommerce.append(((list(df4['Ecommerce']).count('Woocommerce'))/n_Woocommerce)*100)
    BigCommerce.append(((list(df4['Ecommerce']).count('BigCommerce'))/n_BigCommerce)*100)
    Sylius.append(((list(df4['Ecommerce']).count('Sylius'))/n_Sylius)*100)
    Django_oscar.append(((list(df4['Ecommerce']).count('Django-oscar'))/n_Django_oscar)*100)
    Virtocommerce.append(((list(df4['Ecommerce']).count('Virtocommerce'))/n_Virtocommerce)*100)

   

        #     Others.append((len(Others_n1)/n_Others)*100)
#     Magento.append((len(Magento_n1)/n_Magento)*100)
    
    
dict={'Topic':Topic,'Others':Others,'E_commerce':E_commerce ,'Magento':Magento, 'OsCommerce':OsCommerce,'Satchmo':Satchmo,'Virtuemart':Virtuemart, 'Ubercart':Ubercart, 'Prestashop':Prestashop, 'Opencart':Opencart, 'Zencart':Zencart, 'nopCommerce':nopCommerce, 'Shopify':Shopify, 'Hybris':Hybris, 'Broadleaf_commerce':Broadleaf_commerce, 'Woocommerce':Woocommerce,'BigCommerce':BigCommerce, 'Sylius':Sylius, 'Django_oscar':Django_oscar,'Virtocommerce':Virtocommerce   }

mapped=pd.DataFrame(dict)

mapped.to_csv("topic_mapped_by_Ecommerce.csv")    

        

# #"""

# %%
import re
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('New_topic') 


 
Others=[]
E_commerce= []
Magento= []
OsCommerce=[]
Satchmo= []
Virtuemart= []
Ubercart= []
Prestashop= []
Opencart= []
Zencart=[]
nopCommerce= []
Shopify=[]
Hybris=[]
Broadleaf_commerce=[]
Woocommerce=[]
BigCommerce=[]
Sylius=[]
Django_oscar=[]
Virtocommerce=[]

Topic=[]

#no of posts after manual categorization
n_Others=30868
n_E_commerce= 3121
n_Magento= 38186
n_OsCommerce=320
n_Satchmo= 118
n_Virtuemart= 680
n_Ubercart= 327
n_Prestashop= 5788
n_Opencart= 5306
n_Zencart=266
n_nopCommerce= 1104
n_Shopify=4702
n_Hybris=1288
n_Broadleaf_commerce=295
n_Woocommerce=20263
n_BigCommerce=1306
n_Sylius=578
n_Django_oscar=318
n_Virtocommerce=115

 

for i in range(0, 17):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Ecommerce']).count('Others'))/len(df_PM))*100)
    E_commerce.append(((list(df4['Ecommerce']).count('E-commerce'))/len(df_PM))*100)
    Magento.append(((list(df4['Ecommerce']).count('Magento'))/len(df_PM))*100)
    OsCommerce.append(((list(df4['Ecommerce']).count('OsCommerce'))/len(df_PM))*100)
    Satchmo.append(((list(df4['Ecommerce']).count('Satchmo'))/len(df_PM))*100)
    Virtuemart.append(((list(df4['Ecommerce']).count('Virtuemart'))/len(df_PM))*100)
    Ubercart.append(((list(df4['Ecommerce']).count('Ubercart'))/len(df_PM))*100)
    Prestashop.append(((list(df4['Ecommerce']).count('Prestashop'))/len(df_PM))*100)
    Opencart.append(((list(df4['Ecommerce']).count('Opencart'))/len(df_PM))*100)
    Zencart.append(((list(df4['Ecommerce']).count('Zencart'))/len(df_PM))*100)
    nopCommerce.append(((list(df4['Ecommerce']).count('nopCommerce'))/len(df_PM))*100)
    Shopify.append(((list(df4['Ecommerce']).count('Shopify'))/len(df_PM))*100)
    Hybris.append(((list(df4['Ecommerce']).count('Hybris'))/len(df_PM))*100)
    Broadleaf_commerce.append(((list(df4['Ecommerce']).count('Broadleaf-commerce'))/len(df_PM))*100)
    Woocommerce.append(((list(df4['Ecommerce']).count('Woocommerce'))/len(df_PM))*100)
    BigCommerce.append(((list(df4['Ecommerce']).count('BigCommerce'))/len(df_PM))*100)
    Sylius.append(((list(df4['Ecommerce']).count('Sylius'))/len(df_PM))*100)
    Django_oscar.append(((list(df4['Ecommerce']).count('Django-oscar'))/len(df_PM))*100)
    Virtocommerce.append(((list(df4['Ecommerce']).count('Virtocommerce'))/len(df_PM))*100)

   

        #     Others.append((len(Others_n1)/n_Others)*100)
#     Magento.append((len(Magento_n1)/n_Magento)*100)
    
    
dict={'Topic':Topic,'Magento':Magento, 'OsCommerce':OsCommerce,'Satchmo':Satchmo,'Virtuemart':Virtuemart, 'Ubercart':Ubercart, 'Prestashop':Prestashop, 'Opencart':Opencart, 'Zencart':Zencart, 'nopCommerce':nopCommerce, 'Shopify':Shopify, 'Hybris':Hybris, 'Broadleaf_commerce':Broadleaf_commerce, 'Woocommerce':Woocommerce,'BigCommerce':BigCommerce, 'Sylius':Sylius, 'Django_oscar':Django_oscar,'Virtocommerce':Virtocommerce, 'Others':Others,'E_commerce':E_commerce    }

mapped=pd.DataFrame(dict)

mapped.to_csv("topic_mapped_by_Ecommerce.csv")    

        

# #"""

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import os

os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

sns.set(rc={'figure.figsize':(2.5,2.5)}, font="Times New Roman") 
# Data set

df = pd.read_csv("topic_mapped_by_Ecommerce.csv")
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
df = df.set_index('Topic')
 
plt.figure(figsize = (5,5))
# If we do a heatmap, we just observe that a column as higher values than others:
#sns.heatmap(df, cmap='viridis')
#sns.plt.show()
 
# Now if we normalize it by column:
#df_norm_col=(df-df.mean())/df.std()
#sns.heatmap(df_norm_col, cmap='viridis')
#sns.plt.show()

#cmap = sns.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)


ax=sns.heatmap(df, cmap='Blues', annot=True, annot_kws={"size": 6})
ax.xaxis.set_ticks_position('top')
#ax.invert_yaxis()
#sns.set(rc={'figure.figsize':(8,8)})
#sns.set(font="Times New Roman")
#plt.figure(figsize=(12, 9))
#sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_style({'font.family': 'Arial'})
plt.xticks(rotation=90)
plt.tick_params(axis=u'both', which=u'both',length=0)
#plt.xlabel("Ecommerce Platforms", loc='top')
#plt.set_label_position('top')
#plt.gca().axes.xaxis.set_tick([])
#plt.axis('off')
plt.savefig("Topic_vs_platform.svg")
plt.show()

# %% [markdown]
# **Mapping topic vs Technology Stack**

# %%
import re
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('theme') 


 
Others=[]
E_commerce= []
Magento= []
OsCommerce=[]
Satchmo= []
Virtuemart= []
Ubercart= []
Prestashop= []
Opencart= []
Zencart=[]
nopCommerce= []
Shopify=[]
Hybris=[]
Broadleaf_commerce=[]
Woocommerce=[]
BigCommerce=[]
Sylius=[]
Django_oscar=[]
Virtocommerce=[]

Topic=[]

#no of posts after manual categorization
n_Others=30868
n_E_commerce= 3121
n_Magento= 38186
n_OsCommerce=320
n_Satchmo= 118
n_Virtuemart= 680
n_Ubercart= 327
n_Prestashop= 5788
n_Opencart= 5306
n_Zencart=266
n_nopCommerce= 1104
n_Shopify=4702
n_Hybris=1288
n_Broadleaf_commerce=295
n_Woocommerce=20263
n_BigCommerce=1306
n_Sylius=578
n_Django_oscar=318
n_Virtocommerce=115

 

for i in range(0, 5):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Ecommerce']).count('Others'))/len(df_PM))*100)
    E_commerce.append(((list(df4['Ecommerce']).count('E-commerce'))/len(df_PM))*100)
    Magento.append(((list(df4['Ecommerce']).count('Magento'))/len(df_PM))*100)
    OsCommerce.append(((list(df4['Ecommerce']).count('OsCommerce'))/len(df_PM))*100)
    Satchmo.append(((list(df4['Ecommerce']).count('Satchmo'))/len(df_PM))*100)
    Virtuemart.append(((list(df4['Ecommerce']).count('Virtuemart'))/len(df_PM))*100)
    Ubercart.append(((list(df4['Ecommerce']).count('Ubercart'))/len(df_PM))*100)
    Prestashop.append(((list(df4['Ecommerce']).count('Prestashop'))/len(df_PM))*100)
    Opencart.append(((list(df4['Ecommerce']).count('Opencart'))/len(df_PM))*100)
    Zencart.append(((list(df4['Ecommerce']).count('Zencart'))/len(df_PM))*100)
    nopCommerce.append(((list(df4['Ecommerce']).count('nopCommerce'))/len(df_PM))*100)
    Shopify.append(((list(df4['Ecommerce']).count('Shopify'))/len(df_PM))*100)
    Hybris.append(((list(df4['Ecommerce']).count('Hybris'))/len(df_PM))*100)
    Broadleaf_commerce.append(((list(df4['Ecommerce']).count('Broadleaf-commerce'))/len(df_PM))*100)
    Woocommerce.append(((list(df4['Ecommerce']).count('Woocommerce'))/len(df_PM))*100)
    BigCommerce.append(((list(df4['Ecommerce']).count('BigCommerce'))/len(df_PM))*100)
    Sylius.append(((list(df4['Ecommerce']).count('Sylius'))/len(df_PM))*100)
    Django_oscar.append(((list(df4['Ecommerce']).count('Django-oscar'))/len(df_PM))*100)
    Virtocommerce.append(((list(df4['Ecommerce']).count('Virtocommerce'))/len(df_PM))*100)

   

        #     Others.append((len(Others_n1)/n_Others)*100)
#     Magento.append((len(Magento_n1)/n_Magento)*100)
    
    
dict={'Topic':Topic,'Magento':Magento, 'OsCommerce':OsCommerce,'Satchmo':Satchmo,'Virtuemart':Virtuemart, 'Ubercart':Ubercart, 'Prestashop':Prestashop, 'Opencart':Opencart, 'Zencart':Zencart, 'nopCommerce':nopCommerce, 'Shopify':Shopify, 'Hybris':Hybris, 'Broadleaf_commerce':Broadleaf_commerce, 'Woocommerce':Woocommerce,'BigCommerce':BigCommerce, 'Sylius':Sylius, 'Django_oscar':Django_oscar,'Virtocommerce':Virtocommerce ,'E_commerce':E_commerce ,'Others':Others  }

mapped=pd.DataFrame(dict)

mapped.to_csv("topic_mapped_by_theme.csv")    

        

# #"""

# %%
import re
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('theme') 


 
Others=[]
E_commerce= []
Magento= []
OsCommerce=[]
Satchmo= []
Virtuemart= []
Ubercart= []
Prestashop= []
Opencart= []
Zencart=[]
nopCommerce= []
Shopify=[]
Hybris=[]
Broadleaf_commerce=[]
Woocommerce=[]
BigCommerce=[]
Sylius=[]
Django_oscar=[]
Virtocommerce=[]

Topic=[]

#no of posts after manual categorization
n_Others=30868
n_E_commerce= 3121
n_Magento= 38186
n_OsCommerce=320
n_Satchmo= 118
n_Virtuemart= 680
n_Ubercart= 327
n_Prestashop= 5788
n_Opencart= 5306
n_Zencart=266
n_nopCommerce= 1104
n_Shopify=4702
n_Hybris=1288
n_Broadleaf_commerce=295
n_Woocommerce=20263
n_BigCommerce=1306
n_Sylius=578
n_Django_oscar=318
n_Virtocommerce=115

 

for i in range(0, 5):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Ecommerce']).count('Others'))/len(df_PM))*100)
    E_commerce.append(((list(df4['Ecommerce']).count('E-commerce'))/len(df_PM))*100)
    Magento.append(((list(df4['Ecommerce']).count('Magento'))/len(df_PM))*100)
    OsCommerce.append(((list(df4['Ecommerce']).count('OsCommerce'))/len(df_PM))*100)
    Satchmo.append(((list(df4['Ecommerce']).count('Satchmo'))/len(df_PM))*100)
    Virtuemart.append(((list(df4['Ecommerce']).count('Virtuemart'))/len(df_PM))*100)
    Ubercart.append(((list(df4['Ecommerce']).count('Ubercart'))/len(df_PM))*100)
    Prestashop.append(((list(df4['Ecommerce']).count('Prestashop'))/len(df_PM))*100)
    Opencart.append(((list(df4['Ecommerce']).count('Opencart'))/len(df_PM))*100)
    Zencart.append(((list(df4['Ecommerce']).count('Zencart'))/len(df_PM))*100)
    nopCommerce.append(((list(df4['Ecommerce']).count('nopCommerce'))/len(df_PM))*100)
    Shopify.append(((list(df4['Ecommerce']).count('Shopify'))/len(df_PM))*100)
    Hybris.append(((list(df4['Ecommerce']).count('Hybris'))/len(df_PM))*100)
    Broadleaf_commerce.append(((list(df4['Ecommerce']).count('Broadleaf-commerce'))/len(df_PM))*100)
    Woocommerce.append(((list(df4['Ecommerce']).count('Woocommerce'))/len(df_PM))*100)
    BigCommerce.append(((list(df4['Ecommerce']).count('BigCommerce'))/len(df_PM))*100)
    Sylius.append(((list(df4['Ecommerce']).count('Sylius'))/len(df_PM))*100)
    Django_oscar.append(((list(df4['Ecommerce']).count('Django-oscar'))/len(df_PM))*100)
    Virtocommerce.append(((list(df4['Ecommerce']).count('Virtocommerce'))/len(df_PM))*100)

   

        #     Others.append((len(Others_n1)/n_Others)*100)
#     Magento.append((len(Magento_n1)/n_Magento)*100)
    
    
dict={'Topic':Topic,'Magento':Magento, 'OsCommerce':OsCommerce,'Satchmo':Satchmo,'Virtuemart':Virtuemart, 'Ubercart':Ubercart, 'Prestashop':Prestashop, 'Opencart':Opencart, 'Zencart':Zencart, 'nopCommerce':nopCommerce, 'Shopify':Shopify, 'Hybris':Hybris, 'Broadleaf_commerce':Broadleaf_commerce, 'Woocommerce':Woocommerce,'BigCommerce':BigCommerce, 'Sylius':Sylius, 'Django_oscar':Django_oscar,'Virtocommerce':Virtocommerce ,'E_commerce':E_commerce ,'Others':Others  }

mapped=pd.DataFrame(dict)

mapped.to_csv("topic_mapped_by_theme.csv")

# %%
import re
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('theme') 


 
Others=[]
E_commerce= []
Magento= []
OsCommerce=[]
Satchmo= []
Virtuemart= []
Ubercart= []
Prestashop= []
Opencart= []
Zencart=[]
nopCommerce= []
Shopify=[]
Hybris=[]
Broadleaf_commerce=[]
Woocommerce=[]
BigCommerce=[]
Sylius=[]
Django_oscar=[]
Virtocommerce=[]

Topic=[]

#no of posts after manual categorization
n_Others=30868
n_E_commerce= 3121
n_Magento= 38186
n_OsCommerce=320
n_Satchmo= 118
n_Virtuemart= 680
n_Ubercart= 327
n_Prestashop= 5788
n_Opencart= 5306
n_Zencart=266
n_nopCommerce= 1104
n_Shopify=4702
n_Hybris=1288
n_Broadleaf_commerce=295
n_Woocommerce=20263
n_BigCommerce=1306
n_Sylius=578
n_Django_oscar=318
n_Virtocommerce=115

 

for i in range(0, 5):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Ecommerce']).count('Others'))/n_Others)*100)
    E_commerce.append(((list(df4['Ecommerce']).count('E-commerce'))/n_E_commerce)*100)
    Magento.append(((list(df4['Ecommerce']).count('Magento'))/n_Magento)*100)
    OsCommerce.append(((list(df4['Ecommerce']).count('OsCommerce'))/n_OsCommerce)*100)
    Satchmo.append(((list(df4['Ecommerce']).count('Satchmo'))/n_Satchmo)*100)
    Virtuemart.append(((list(df4['Ecommerce']).count('Virtuemart'))/n_Virtuemart)*100)
    Ubercart.append(((list(df4['Ecommerce']).count('Ubercart'))/n_Ubercart)*100)
    Prestashop.append(((list(df4['Ecommerce']).count('Prestashop'))/n_Prestashop)*100)
    Opencart.append(((list(df4['Ecommerce']).count('Opencart'))/n_Opencart)*100)
    Zencart.append(((list(df4['Ecommerce']).count('Zencart'))/n_Zencart)*100)
    nopCommerce.append(((list(df4['Ecommerce']).count('nopCommerce'))/n_nopCommerce)*100)
    Shopify.append(((list(df4['Ecommerce']).count('Shopify'))/n_Shopify)*100)
    Hybris.append(((list(df4['Ecommerce']).count('Hybris'))/n_Hybris)*100)
    Broadleaf_commerce.append(((list(df4['Ecommerce']).count('Broadleaf-commerce'))/n_Broadleaf_commerce)*100)
    Woocommerce.append(((list(df4['Ecommerce']).count('Woocommerce'))/n_Woocommerce)*100)
    BigCommerce.append(((list(df4['Ecommerce']).count('BigCommerce'))/n_BigCommerce)*100)
    Sylius.append(((list(df4['Ecommerce']).count('Sylius'))/n_Sylius)*100)
    Django_oscar.append(((list(df4['Ecommerce']).count('Django-oscar'))/n_Django_oscar)*100)
    Virtocommerce.append(((list(df4['Ecommerce']).count('Virtocommerce'))/n_Virtocommerce)*100)

   

        #     Others.append((len(Others_n1)/n_Others)*100)
#     Magento.append((len(Magento_n1)/n_Magento)*100)
    
    
dict={'Topic':Topic,'Magento':Magento, 'OsCommerce':OsCommerce,'Satchmo':Satchmo,'Virtuemart':Virtuemart, 'Ubercart':Ubercart, 'Prestashop':Prestashop, 'Opencart':Opencart, 'Zencart':Zencart, 'nopCommerce':nopCommerce, 'Shopify':Shopify, 'Hybris':Hybris, 'Broadleaf_commerce':Broadleaf_commerce, 'Woocommerce':Woocommerce,'BigCommerce':BigCommerce, 'Sylius':Sylius, 'Django_oscar':Django_oscar,'Virtocommerce':Virtocommerce ,'E_commerce':E_commerce ,'Others':Others  }

mapped=pd.DataFrame(dict)

mapped.to_csv("topic_mapped_by_theme.csv")

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import os

os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

sns.set(rc={'figure.figsize':(1.5,2.5)}, font="Times New Roman") 
# Data set

df = pd.read_csv("topic_mapped_by_theme.csv")
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
df = df.set_index('Theme')
 
plt.figure(figsize = (5,1.5))
# If we do a heatmap, we just observe that a column as higher values than others:
#sns.heatmap(df, cmap='viridis')
#sns.plt.show()
 
# Now if we normalize it by column:
#df_norm_col=(df-df.mean())/df.std()
#sns.heatmap(df_norm_col, cmap='viridis')
#sns.plt.show()

#cmap = sns.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)


ax=sns.heatmap(df, cmap='Blues', annot=True, annot_kws={"size": 6})
ax.xaxis.set_ticks_position('top')
#ax.invert_yaxis()
#sns.set(rc={'figure.figsize':(8,8)})
#sns.set(font="Times New Roman")
#plt.figure(figsize=(12, 9))
#sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_style({'font.family': 'Arial'})
plt.xticks(rotation=90)
plt.tick_params(axis=u'both', which=u'both',length=0)
#plt.xlabel("Ecommerce Platforms", loc='top')
#plt.set_label_position('top')
#plt.gca().axes.xaxis.set_tick([])
#plt.axis('off')
plt.savefig("Theme_vs_platform.svg")
plt.show()

# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
import statistics
import os

os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

#df1=pd.read_csv("RQ1_ecommerce_version_1.csv",low_memory=False)
df2=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False )
df2.columns
# Out:
# Index(['Unnamed: 0', 'tags', 'Programming', 'Business', 'Technology',
#        'Ecommerce', 'Old_topic', 'New_topic', 'theme', 'theme_id',
#        'topic_name', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords',
#        'AcceptedAnswerId', 'AnswerCount', 'Body', 'CommentCount',
#        'CommunityOwnedDate', 'CreationDate', 'FavoriteCount', 'Id',
#        'OwnerUserId', 'Score', 'Tags', 'Title', 'ViewCount'],
#       dtype='object')

# %% [markdown]
# **Theme versus Technology Stack**

# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('theme') 


 
Others= []
PhP_MySQL=[]
Django=[]
PhP_Symphony_MySQL=[]
ASP_NET_MS_SQL=[]
Rails_GraphQL=[]
Java_SAP_hybris=[]
Spring_Hibernate=[]
Node_js=[]
PhP_Symphony=[]
ASP_NET_GraphQL=[]

Topic=[]

#no of posts after manual categorization
n_Others= 33989
n_PhP_MySQL=65348
n_Django=436
n_PhP_Symphony_MySQL=5788
n_ASP_NET_MS_SQL=1104
n_Rails_GraphQL=4702
n_Java_SAP_hybris=1288
n_Spring_Hibernate=295
n_Node_js=1306
n_PhP_Symphony=578
n_ASP_NET_GraphQL=115

for i in range(0, 5):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Technology']).count('Others'))/len(df_PM))*100)
    Django.append(((list(df4['Technology']).count('Django'))/len(df_PM))*100)
    PhP_MySQL.append(((list(df4['Technology']).count('PhP, MySQL'))/len(df_PM))*100)
    PhP_Symphony_MySQL.append(((list(df4['Technology']).count('PhP, Symphony, MySQL'))/len(df_PM))*100)
    ASP_NET_MS_SQL.append(((list(df4['Technology']).count('ASP.NET,  MS SQL'))/len(df_PM))*100)
    Rails_GraphQL.append(((list(df4['Technology']).count('Rails, GraphQL'))/len(df_PM))*100)
    Java_SAP_hybris.append(((list(df4['Technology']).count('Java, SAP hybris'))/len(df_PM))*100)
    Spring_Hibernate.append(((list(df4['Technology']).count('Spring, Hibernate'))/len(df_PM))*100)
    Node_js.append(((list(df4['Technology']).count('Node.js'))/len(df_PM))*100)
    PhP_Symphony.append(((list(df4['Technology']).count('PhP, Symphony'))/len(df_PM))*100)
    ASP_NET_GraphQL.append(((list(df4['Technology']).count('ASP.NET, GraphQL'))/len(df_PM))*100)
   
    
    
dict={'Topic':Topic,'Django':Django, 'PhP, MySQL':PhP_MySQL,'PhP, Symphony, MySQL':PhP_Symphony_MySQL,'ASP.NET, MS SQL':ASP_NET_MS_SQL, 'Rails, GraphQL':Rails_GraphQL, 'Java, SAP hybris':Java_SAP_hybris, 'Spring, Hibernate':Spring_Hibernate, 'Node.js':Node_js, 'PhP, Symphony':PhP_Symphony, 'ASP.NET, GraphQL':ASP_NET_GraphQL ,'Others':Others  }

mapped=pd.DataFrame(dict)

mapped.to_csv("technology_mapped_by_theme.csv")

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import os

os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

sns.set(rc={'figure.figsize':(2.5,2.5)}, font="Times New Roman") 
# Data set

df = pd.read_csv("technology_mapped_by_theme.csv")
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
df = df.set_index('Theme')
 
plt.figure(figsize = (3.5,1.5))
# If we do a heatmap, we just observe that a column as higher values than others:
#sns.heatmap(df, cmap='viridis')
#sns.plt.show()
 
# Now if we normalize it by column:
#df_norm_col=(df-df.mean())/df.std()
#sns.heatmap(df_norm_col, cmap='viridis')
#sns.plt.show()

#cmap = sns.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)


ax=sns.heatmap(df, cmap='Blues', annot=True, annot_kws={"size": 6})
ax.xaxis.set_ticks_position('top')
#ax.invert_yaxis()
#sns.set(rc={'figure.figsize':(8,8)})
#sns.set(font="Times New Roman")
#plt.figure(figsize=(12, 9))
#sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_style({'font.family': 'Arial'})
plt.xticks(rotation=90)
plt.tick_params(axis=u'both', which=u'both',length=0)
#plt.xlabel("Ecommerce Platforms", loc='top')
#plt.set_label_position('top')
#plt.gca().axes.xaxis.set_tick([])
#plt.axis('off')
plt.savefig("Theme_vs_TechnologyStack.svg")
plt.show()

# %% [markdown]
# **Topic Mapped with Technology Stack**

# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)


#df_PM_topics=pd.read_csv("syc08_PM_all_question_post_12_6_20.csv", low_memory=False)

#"""
gk = df_PM.groupby('New_topic') 


Others= []
PhP_MySQL=[]
Django=[]
PhP_Symphony_MySQL=[]
ASP_NET_MS_SQL=[]
Rails_GraphQL=[]
Java_SAP_hybris=[]
Spring_Hibernate=[]
Node_js=[]
PhP_Symphony=[]
ASP_NET_GraphQL=[]

Topic=[]

#no of posts after manual categorization
n_Others= 33989
n_PhP_MySQL=65348
n_Django=436
n_PhP_Symphony_MySQL=5788
n_ASP_NET_MS_SQL=1104
n_Rails_GraphQL=4702
n_Java_SAP_hybris=1288
n_Spring_Hibernate=295
n_Node_js=1306
n_PhP_Symphony=578
n_ASP_NET_GraphQL=115

for i in range(0, 17):
    Topic.append(i)
    data=gk.get_group(i)
    df4=data.reset_index()
    
    Others.append(((list(df4['Technology']).count('Others'))/len(df_PM))*100)
    Django.append(((list(df4['Technology']).count('Django'))/len(df_PM))*100)
    PhP_MySQL.append(((list(df4['Technology']).count('PhP, MySQL'))/len(df_PM))*100)
    PhP_Symphony_MySQL.append(((list(df4['Technology']).count('PhP, Symphony, MySQL'))/len(df_PM))*100)
    ASP_NET_MS_SQL.append(((list(df4['Technology']).count('ASP.NET,  MS SQL'))/len(df_PM))*100)
    Rails_GraphQL.append(((list(df4['Technology']).count('Rails, GraphQL'))/len(df_PM))*100)
    Java_SAP_hybris.append(((list(df4['Technology']).count('Java, SAP hybris'))/len(df_PM))*100)
    Spring_Hibernate.append(((list(df4['Technology']).count('Spring, Hibernate'))/len(df_PM))*100)
    Node_js.append(((list(df4['Technology']).count('Node.js'))/len(df_PM))*100)
    PhP_Symphony.append(((list(df4['Technology']).count('PhP, Symphony'))/len(df_PM))*100)
    ASP_NET_GraphQL.append(((list(df4['Technology']).count('ASP.NET, GraphQL'))/len(df_PM))*100)
   
    
    
dict={'Topic':Topic,'Django':Django, 'PhP, MySQL':PhP_MySQL,'PhP, Symphony, MySQL':PhP_Symphony_MySQL,'ASP.NET, MS SQL':ASP_NET_MS_SQL, 'Rails, GraphQL':Rails_GraphQL, 'Java, SAP hybris':Java_SAP_hybris, 'Spring, Hibernate':Spring_Hibernate, 'Node.js':Node_js, 'PhP, Symphony':PhP_Symphony, 'ASP.NET, GraphQL':ASP_NET_GraphQL ,'Others':Others  }

mapped=pd.DataFrame(dict)

mapped.to_csv("technology_mapped_by_topic.csv")

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import os

os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

sns.set(rc={'figure.figsize':(2.5,2.5)}, font="Times New Roman") 
# Data set

df = pd.read_csv("technology_mapped_by_topic.csv")
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
df = df.set_index('Topic')
 
plt.figure(figsize = (3.5,5))
# If we do a heatmap, we just observe that a column as higher values than others:
#sns.heatmap(df, cmap='viridis')
#sns.plt.show()
 
# Now if we normalize it by column:
#df_norm_col=(df-df.mean())/df.std()
#sns.heatmap(df_norm_col, cmap='viridis')
#sns.plt.show()

#cmap = sns.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)


ax=sns.heatmap(df, cmap='Blues', annot=True, annot_kws={"size": 6})
ax.xaxis.set_ticks_position('top')
#ax.invert_yaxis()
#sns.set(rc={'figure.figsize':(8,8)})
#sns.set(font="Times New Roman")
#plt.figure(figsize=(12, 9))
#sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_style({'font.family': 'Arial'})
plt.xticks(rotation=90)
plt.tick_params(axis=u'both', which=u'both',length=0)
#plt.xlabel("Ecommerce Platforms", loc='top')
#plt.set_label_position('top')
#plt.gca().axes.xaxis.set_tick([])
#plt.axis('off')
plt.savefig("Topic_vs_TechnologyStack.svg")
plt.show()

# %% [markdown]
# **Sample Creation for RQ2**

# %%
import re
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import numpy as np
import random
import os

#Please specify your dataset directory. 
os.chdir("F:/1_NAIST_Research_SE/SE_meeting/Ecommerce/modified/")

df_PM=pd.read_csv("Mapped_ecommerce_post_dataset.csv",low_memory=False)

# %%
data=df_PM.sample(n=383)
data.to_csv("RQ2_ecommerce_samples.csv")

# %%
((list(df4['Ecommerce']).count('Others'))/n_Others[0])*100
# Out:
# 12.433588181935985

# %%
import pandas as pd
import numpy as np
import plotly.figure_factory as ff

def gen_heat_map(input_file):
    data_table = pd.read_csv('%s.csv'%(input_file), index_col=0).transpose()
    x = list(data_table.axes[1])
    y = list(filter(lambda w: w != 'Others', data_table.axes[0]))
    z = np.round(data_table.to_numpy(), decimals=2)
    #fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Grays')
    fig = ff.create_annotated_heatmap(z, x=x, y=y, colorscale='gray', showscale=True, zmax=100, zmin=0, reversescale=True)
    fig.write_image('%s.pdf'%(input_file))

if __name__ == '__main__':
    #gen_heat_map('topic_10_language_mapping_27_6_2020')
    #gen_heat_map('topic_10_Environment_mapping_result_26_6_2020')
    #gen_heat_map('topic_10_Dependency_mapping_result_27_6_20')
    #gen_heat_map('topic_10_PM_mapping_result_27_6_2020')
    gen_heat_map('topic_3_PM_mapping_result_27_6_2020')
